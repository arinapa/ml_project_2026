# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/grades.csv", sep= ';')
df.head()


df[df["program"] == "Прикладной анализ данных и искусственный интеллект"]
# Out:
# /tmp/ipykernel_61430/5730130.py:1: DtypeWarning: Columns (0: course, 1: module, 2: academic_year) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/raw/grades.csv", sep= ';')
#                           student_id_hash                     campus  \
# 63896    590e486262f8d6535aaa9b9778c8586f  НИУ ВШЭ - Санкт-Петербург
# 63927    51fa6fd4677884c4da2480982bb94c6e  НИУ ВШЭ - Санкт-Петербург
# 63930    dadf51709e1817d350306f3e8c03680c  НИУ ВШЭ - Санкт-Петербург
# 63967    aac0ece290e37b40f977d0c3be121321  НИУ ВШЭ - Санкт-Петербург
# 64813    bbf56a3420be5fc941ef0bd5a6a0a24b  НИУ ВШЭ - Санкт-Петербург
# ...                                   ...                        ...
# 1744133  72006d3989aff87cc9dfdb2838c6cfaa  НИУ ВШЭ - Санкт-Петербург
# 1744134  c21eec00a9757200e0ddb1fc27e8a60e  НИУ ВШЭ - Санкт-Петербург
# 1744135  c21eec00a9757200e0ddb1fc27e8a60e  НИУ ВШЭ - Санкт-Петербург
# ...
